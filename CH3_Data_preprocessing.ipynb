# %% [markdown]
# <a href="https://colab.research.google.com/github/Narawit007/BSC_DPDM2025/blob/main/CH3_Data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
flood = pd.read_csv('/content/drive/MyDrive/BSC_data 2026/flooding database.csv')
flood.head()
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing Data

# %%
flood.isnull().any()
# Out:
# system:index         False
# index                False
# threshold_type       False
# glide_index           True
# dfo_country          False
# dfo_other_country     True
# dfo_centroid_x       False
# dfo_centroid_y       False
# dfo_began            False
# dfo_ended             True
# dfo_validation        True
# dfo_dead             False
# dfo_displaced        False
# dfo_cause             True
# dfo_severity         False
# gfd_area             False
# gfd_exp_ghsl_ts       True
# gfd_exp_ghsl_2000     True
# gfd_exp_ghsl_2015    False
# Errors               False
# dif 2000             False
# dif 2015             False
# error 2000            True
# dtype: bool

# %%
flood.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### drop record ที่มี missing ออก

# %% [markdown]
# ### check missing data

# %% [markdown]
# ### Drop record ที่มี missing ออก

# %% [markdown]
# drop ถ้ามี missing

# %%
flood.shape
# Out:
# (913, 23)

# %%
flood_drop1 = flood.dropna()
flood_drop1.shape
# Out:
# (13, 23)

# %% [markdown]
# drop เฉพาะเกิด missing ในตัวแปรที่เราจะใช้
#
# -dfo_country
#
# -dfo_other_country
#
# -dfo_began
#
# -dfo_ended
#
# -dfo_dead
#
# -dfo_cause
#
# -dfo_severity

# %%
flood_drop2 = flood.dropna(subset = ['dfo_country', 'dfo_other_country', 'dfo_began',
                                        'dfo_ended', 'dfo_dead', 'dfo_cause', 'dfo_severity'])
flood_drop2.shape
# Out:
# (637, 23)

# %%
flood_drop2.head()
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# ...

# %% [markdown]
# ### เติม dummy

# %%
flood[flood.isnull()['dfo_other_country']]
# Out:
#                            system:index  index threshold_type  \
# 172  DFO_2415_From_20040110_to_20040119   2415            std
# 383  DFO_3089_From_20070530_to_20070603   3089            std
# 387  DFO_3097_From_20070611_to_20070624   3097            std
# 412  DFO_3136_From_20070721_to_20071015   3136            std
# 428  DFO_3166_From_20070726_to_20071010   3166            std
# ..                                  ...    ...            ...
# 908  DFO_4683_From_20180901_to_20181002   4683            std
# 909  DFO_4695_From_20181023_to_20181027   4695            std
# 910  DFO_4703_From_20181029_to_20181107   4703           otsu
# 911  DFO_4704_From_20181124_to_20181129   4704            std
# 912  DFO_4711_From_20181205_to_20181210   4711            std
#
#             glide_index         dfo_country dfo_other_country  dfo_centroid_x  \
# 172                   0                Iran               NaN       51.439491
# ...

# %%
flood[~flood.isnull()['dfo_other_country']]
# Out:
#                            system:index  index threshold_type  \
# 0    DFO_1586_From_20000218_to_20000301   1586           otsu
# 1    DFO_1587_From_20000217_to_20000311   1587           otsu
# 2    DFO_1595_From_20000405_to_20000425   1595           otsu
# 3    DFO_1614_From_20000711_to_20000810   1614           otsu
# 4    DFO_1627_From_20000830_to_20000910   1627           otsu
# ..                                  ...    ...            ...
# 880  DFO_4516_From_20170908_to_20170919   4516            std
# 886  DFO_4581_From_20180310_to_20180314   4581            std
# 893  DFO_4597_From_20180325_to_20180408   4597            std
# 897  DFO_4640_From_20180625_to_20180711   4640            std
# 902  DFO_4662_From_20180726_to_20180904   4662            std
#
#             glide_index dfo_country       dfo_other_country  dfo_centroid_x  \
# 0                     0   Australia                       0      143.697800
# ...

# %%
flood_filldummy = flood.fillna(value = {'dfo_other_country' : 'Unknown'})

# %%
flood_filldummy.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country      0
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### เติม ด้วยค่ากลาง

# %%
flood.groupby('dfo_cause').count()
# Out:
#                        system:index  index  threshold_type  glide_index  \
# dfo_cause
# Dam                              13     13              13           11
# Heavy rain                      749    749             749          554
# Snowmelt, Ice, Rain              52     52              52           45
# Tropical Storm, Surge            97     97              97           71
#
#                        dfo_country  dfo_other_country  dfo_centroid_x  \
# dfo_cause
# Dam                             13                 10              13
# Heavy rain                     749                530             749
# Snowmelt, Ice, Rain             52                 45              52
# Tropical Storm, Surge           97                 53              97
#
#                        dfo_centroid_y  dfo_began  dfo_ended  ...  \
# dfo_cause                                                    ...
# Dam                                13         13         13  ...
# ...

# %%
flood_fillmode = flood.fillna(value = {'dfo_cause' : 'Heavy rain'})

# %%
flood_fillmode.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### เติม ด้วยตัวแทนของกลุ่ม

# %%
flood.groupby(['dfo_severity', 'dfo_cause']).count()
# Out:
#                                     system:index  index  threshold_type  \
# dfo_severity dfo_cause
# 1.0          Dam                               9      9               9
#              Heavy rain                      464    464             464
#              Snowmelt, Ice, Rain              34     34              34
#              Tropical Storm, Surge            33     33              33
# 1.5          Dam                               3      3               3
#              Heavy rain                      163    163             163
#              Snowmelt, Ice, Rain               8      8               8
#              Tropical Storm, Surge            26     26              26
# 2.0          Dam                               1      1               1
#              Heavy rain                      122    122             122
#              Snowmelt, Ice, Rain              10     10              10
#              Tropical Storm, Surge            38     38              38
#
# ...

# %%
flood_sever1 = flood[flood['dfo_severity'] == 1.0]
flood_sever15 = flood[flood['dfo_severity'] == 1.5]
flood_sever2 = flood[flood['dfo_severity'] == 2.0]

# %%
flood_fillgroup1 = flood_sever1.fillna({'dfo_cause' : 'Heavy rain'})
flood_fillgroup15= flood_sever15.fillna({'dfo_cause' : 'Heavy rain'})
flood_fillgroup2 = flood_sever2.fillna({'dfo_cause' : 'Tropical Storm, Surge'})

# %%
flood_fillgroup = pd.concat([flood_fillgroup1, flood_fillgroup15, flood_fillgroup2])

# %%
flood_fillgroup.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ## Noisy Data

# %%
flood['gfd_area']
# Out:
# 0        316.73
# 1        228.50
# 2         89.10
# 3       4322.47
# 4        740.33
#          ...
# 908     1866.91
# 909     2720.37
# 910    10019.87
# 911     6467.41
# 912     2475.92
# Name: gfd_area, Length: 913, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(flood['gfd_area'])

# %% [markdown]
# ใช้histogram ดู Bin ที่เหมาะสม

# %%
plt.hist(flood['gfd_area'], 7)
# Out:
# (array([781.,  75.,  38.,   7.,   6.,   3.,   3.]),
#  array([    0.        , 14078.23142857, 28156.46285714, 42234.69428571,
#         56312.92571429, 70391.15714286, 84469.38857143, 98547.62      ]),
#  <BarContainer object of 7 artists>)

# %%
outputhist = plt.hist(flood['gfd_area'], 7)

# %%
outputhist[1]
# Out:
# array([    0.        , 14078.23142857, 28156.46285714, 42234.69428571,
#        56312.92571429, 70391.15714286, 84469.38857143, 98547.62      ])

# %%
def assign_gfd_area_bins(gfd_area_series, bin_edges):
    # Using pd.cut to categorize the 'gfd_area' values into the predefined bins
    # `include_lowest=True` ensures that the lowest value is included in the first bin
    return pd.cut(gfd_area_series, bins=bin_edges, include_lowest=True)

# Apply the function to the 'gfd_area' column and store the result in a new column
flood['gfd_area_bin'] = assign_gfd_area_bins(flood['gfd_area'], outputhist[1])

# Display the first few rows with the new column
print(flood[['gfd_area', 'gfd_area_bin']].head())
# Out:
#    gfd_area          gfd_area_bin
# 0    316.73    (-0.001, 3284.921]
# 1    228.50    (-0.001, 3284.921]
# 2     89.10    (-0.001, 3284.921]
# 3   4322.47  (3284.921, 6569.841]
# 4    740.33    (-0.001, 3284.921]

# %%
def put_value_into_bins(value,bin_edge):
  for i in range(len(bin_edge)-1):
    if value >= bin_edge[1] and value < bin_edge[i+1]:
      new_val = bin_edge[i]+(bin_edge[i+1]-bin_edge[i])/2
      return new_val

# %%
put_value_into_bins(7000,outputhist[1])
# Out:
# np.float64(8212.301666666666)

# %%
flood['gfd_area bin']= flood['gfd_area'].apply(lambda x: put_value_into_bins(x,outputhist[1]))

# %%
plt.plot(flood['gfd_area bin'])

# %%
plt.subplot(2,1,1)
plt.plot(flood['gfd_area bin'])
plt.subplot(2,1,2)
plt.plot(flood['gfd_area bin'])

# %%
plt.subplot(2,1,1)
plt.plot(flood['gfd_area bin'].sort_values().reset_index(drop=True))
plt.subplot(2,1,2)
plt.plot(flood['gfd_area bin'].sort_values().reset_index(drop=True))

# %% [markdown]
# ## Outlier Removal

# %%
outputbox = plt.boxplot(flood['gfd_area'],vert=False,whis=10);

# %%
outputbox
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff68d33cda0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff68d33ca70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff68d33e990>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff68cbf2c60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff68fa1c7d0>],
#  'means': []}

# %%
outputbox['whiskers'][0].get_xdata()
# Out:
# array([608.6,   0. ])

# %%
outputbox['whiskers'][1].get_xdata()
# Out:
# array([ 7354.55, 68991.93])

# %%
outputbox['fliers'][0].get_xdata()
# Out:
# array([98547.62, 79213.43, 75030.8 , 78785.53, 88773.57, 97982.77])

# %% [markdown]
# remove outliers

# %%
flood_nooutlier = flood[flood['gfd_area']<outputbox['whiskers'][1].get_xdata()[1]]

# %%
outputbox2 = plt.boxplot(flood_nooutlier['gfd_area'],vert=False,whis=10);

# %% [markdown]
# ตามหาค่า outliers

# %%
flood[flood['gfd_area'] == outputbox['fliers'][0].get_xdata()[0]]
# Out:
#                            system:index  index threshold_type glide_index  \
# 123  DFO_2208_From_20030416_to_20030528   2208            std           0
#
#     dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 123      Russia                 0       64.739289       55.453563   4/16/03
#
#     dfo_ended  ...  gfd_area  gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  \
# 123   5/28/03  ...  98547.62        1014245.0          1014245.0
#
#     gfd_exp_ghsl_2015  Errors  dif 2000  dif 2015  error 2000  \
# 123            931108       1         0     83137         1.0
#
#               gfd_area_bin  gfd_area bin
# 123  (95262.699, 98547.62]           NaN
#
# [1 rows x 25 columns]
